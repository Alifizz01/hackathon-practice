# %% [markdown]
# # Exploratory Data Analysis
#
# Starter notebook for exploring raw data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

# %%
# Load your data here
# df = pd.read_csv('../data/raw/your_data.csv')
# df.head()
